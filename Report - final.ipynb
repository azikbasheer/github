# %% [markdown]
# # Part 1: Introduction

# %% [markdown]
# The problem we are looking to solve in this report is to identify which neighborhoods are heavily populated in Toronto. This will allow us to see where we should open up a restaurant, as we would like to open one in a heavily populated area. We would also like the income to be high in this area, so consumers will be willing to dine frequently at the restaurant. Future restaurant owners would be interested in this report.

# %% [markdown]
# # Part 2: Data

# %% [markdown]
# Toronto's Census Data: https://www.toronto.ca/city-government/data-research-maps/open-data/open-data-catalogue/#8c732154-5012-9afe-d0cd-ba3ffc813d5a
#
# This data can help identify the neighborhoods that have the highest population and income. This can help narrow down the neighborhoods it would be most beneficial to open up a restaurant in the Toronto area.

# %% [markdown]
# # Part 3: Methodology

# %% [markdown]
# In this part of the report, the code was executed in order to narrow down the options of areas in Toronto with the highest population and income. From the code that was executed it can be understood where the best place it would be for future restaurant owners to potentially open up a restaurant.

# %% [markdown]
# # Part 4: Results

# %% [markdown]
# From the results the top 5 locations to open a new restaurant in Toronto based on income and population are:
#
# St.Andrew-Windfields
#
# Edenbridge-Humber Valley
#
# Lawrence Park North
#
# Annex
#
# Yonge-St.Clair

# %% [markdown]
# # Discussion

# %% [markdown]
# Based on the results, these 5 locations would be the best to open up a restaurant because of their high income and popualtion. However there are also other areas that are either higher in population or income, but not both. These locations may also be good places to open up restauarnts, but will not be as beneficial as they may not receive enough revenue and profit from these extra locations.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Overall, from this project it was conducted to find the top 5 best locations in Toronto to open up a new restaurant based on income and population. The top 5 were St.Andrew-Windfields, Edenbridge-Humber Valley, Lawrence Park North, Annex, and Yonge-St.Clair. However, it is also important to note that several other locations either had high income or population but not both, and they should also be considered but will not be as beneficial.
